# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
churn_data = pd.read_csv('data/churn.csv')

# %%
churn_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# !pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'c:\phython3.9\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'c:\phython3.9\python.exe -m pip install --upgrade pip' command.
# ...

# %%
# %matplotlib inline

# %%
fig = plt.figure(figsize=(12,4))

# %%
clients = churn_data['Exited'].value_counts()
display(clients)
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize=(12,4))
axes = fig.add_axes([0, 0, 1, 1])
axes.pie(clients, labels = clients.index, autopct='%.1f%%', explode = [0.1, 0])
axes.set_title('соотношение ушедших и лояльных клиентов')
# Out:
# Text(0.5, 1.0, 'соотношение ушедших и лояльных клиентов')

# %%
churn_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
bnce2500 = churn_data[churn_data['Balance'] > 2500]['Balance']
fig = plt.figure(figsize=(12,4))
axes = fig.add_axes([0, 0, 1, 1])
axes.hist(
    x=bnce2500,
    bins=20,
    color='lime'
)
# Out:
# (array([3.000e+00, 7.000e+00, 2.500e+01, 5.700e+01, 1.450e+02, 2.730e+02,
#         4.870e+02, 7.680e+02, 1.010e+03, 1.079e+03, 9.500e+02, 6.970e+02,
#         4.190e+02, 2.600e+02, 1.270e+02, 4.600e+01, 2.400e+01, 4.000e+00,
#         1.000e+00, 1.000e+00]),
#  array([  3768.69,  16125.16,  28481.63,  40838.1 ,  53194.57,  65551.04,
#          77907.51,  90263.98, 102620.45, 114976.92, 127333.39, 139689.86,
#         152046.33, 164402.8 , 176759.27, 189115.74, 201472.21, 213828.68,
#         226185.15, 238541.62, 250898.09]),
#  <BarContainer object of 20 artists>)

# %%
import seaborn as sns

# %%
values =churn_data[churn_data['Balance'] > 2500]['Balance']
height =churn_data[churn_data['Balance'] > 2500]['Exited']

# %%
fig = plt.figure(figsize=(12,4))
ddiagram = sns.boxplot(
    data=churn_data,
    x='Balance',
    y='Exited',
     orient='h',
    width=0.9
)

# %%
fig = plt.figure(figsize=(15,5))
diagram_box = sns.boxplot(
    data=churn_data,
    x='Age',
    y='Exited',
    orient='h',
    width=0.9
)

# %%
churn_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
axes.scatter(
    x = churn_data['CreditScore'],
    y = churn_data['EstimatedSalary'],
    s=1000,
    marker='o',
    c = 'red'
)

# %%
jointplot = sns.jointplot(
    data=croped_covid_df, 
    x='people_fully_vaccinated_per_hundred', 
    y='daily_confirmed_per_hundred',
    hue='country',
    xlim = (0, 40),
    ylim = (0, 0.1),
    height=8,
)

# %%
churn_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
jp = sns.jointplot(
    data=churn_data,
    x='CreditScore',
    y='EstimatedSalary',
    hue='Exited',
    xlim = (0, 850),
    ylim = (0, 210000),
    height=8
    )

# %%
fig = plt.figure(figsize=(10, 7))
bp = sns.barplot(
    data=churn_data,
    x='Gender',
    y='Exited',
    
)
bp.set_title('Отток клиентов из банка в зависимости от пола')
# Out:
# Text(0.5, 1.0, 'Отток клиентов из банка в зависимости от пола')

# %%
churn_data['Exited'].mean()
# Out:
# 0.2037

# %%
fig = plt.figure(figsize=(10, 7))
bp = sns.barplot(
    data=churn_data,
    y='Exited',
    x='IsActiveMember',
)

# %%
def get_credit_score_cat(credit_score):
        if credit_score >= 300 and credit_score < 500:
            return "Very_Poor"
        elif credit_score >= 500 and credit_score < 601:
            return "Poor"
        elif credit_score >= 601 and credit_score < 661:
            return "Fair"
        elif credit_score >= 661 and credit_score < 781:
            return "Good"
        elif credit_score >= 781 and credit_score < 851:
            return "Excellent"
        elif credit_score >= 851:
            return "Top"
        elif credit_score < 300:
            return "Deep"

# %%
churn_data['CreditScore'] = churn_data['CreditScore'].apply(get_credit_score_cat)

# %%
pvt = churn_data.pivot_table(
    index='CreditScore',
    columns='Tenure',
    values='Exited'
)
pvt.columns = pvt.columns.astype('string')

# %%
display(pvt)
# Out:
# Tenure             0         1         2         3         4         5   \
# CreditScore
# Excellent    0.275000  0.208333  0.137255  0.168317  0.131868  0.233333
# Fair         0.217391  0.215596  0.213043  0.216450  0.197248  0.206897
# Good         0.203822  0.203608  0.187342  0.205962  0.195122  0.214470
# Poor         0.226415  0.259398  0.211765  0.212245  0.233202  0.199153
# Very_Poor    0.444444  0.253731  0.151515  0.285714  0.293103  0.149254
#
# Tenure             6         7         8         9         10
# CreditScore
# Excellent    0.241379  0.127660  0.196078  0.270833  0.254902
# Fair         0.236364  0.171103  0.209016  0.190045  0.205357
# Good         0.182857  0.191892  0.152355  0.194667  0.197802
# Poor         0.179916  0.151261  0.214575  0.251082  0.169492
# Very_Poor    0.225352  0.206349  0.253521  0.229508  0.333333

# %%
pvt = churn_data.pivot_table(
    index='CreditScore',
    columns='Tenure',
    values='Exited'
)
pvt.columns = pvt.columns.astype('string')
fig = plt.figure(figsize=(15,4))
hmap = sns.heatmap(data=pvt, cmap='YlGnBu')
