# %%
import requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js'
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
#Код ответа в виде числовой переменной можно получить с помощью метода status_code:

print(response.status_code) # Выводим числовое значение response на экран
# Out:
# 200

# %%
url = 'https://www.cbr-xml-daily.ru/daily.xml'
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
print(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# <?xml version="1.0" encoding="windows-1251"?><ValCurs Date="28.09.2024" name="Foreign Currency Market"><Valute ID="R01010"><NumCode>036</NumCode><CharCode>AUD</CharCode><Nominal>1</Nominal><Name>Àâñòðàëèéñêèé äîëëàð</Name><Value>63,7677</Value><VunitRate>63,7677</VunitRate></Valute><Valute ID="R01020A"><NumCode>944</NumCode><CharCode>AZN</CharCode><Nominal>1</Nominal><Name>Àçåðáàéäæàíñêèé ìàíàò</Name><Value>54,5368</Value><VunitRate>54,5368</VunitRate></Valute><Valute ID="R01035"><NumCode>826</NumCode><CharCode>GBP</CharCode><Nominal>1</Nominal><Name>Ôóíò ñòåðëèíãîâ Ñîåäèíåííîãî êîðîëåâñòâà</Name><Value>124,1978</Value><VunitRate>124,1978</VunitRate></Valute><Valute ID="R01060"><NumCode>051</NumCode><CharCode>AMD</CharCode><Nominal>100</Nominal><Name>Àðìÿíñêèõ äðàìîâ</Name><Value>23,9370</Value><VunitRate>0,23937</VunitRate></Valute><Valute ID="R01090B"><NumCode>933</NumCode><CharCode>BYN</CharCode><Nominal>1</Nominal><Name>Áåëîðóññêèé ðóáëü</Name><Value>28,8707</Value><VunitRate>28,8707</VunitRate></Valute><Valute ID="R01100"><NumCode>975</NumCode><CharCode>BGN</CharCode><Nominal>1</Nominal><Name>Áîëãàðñêèé ëåâ</Name><Value>52,8783</Value><VunitRate>52,8783</VunitRate></Valute><Valute ID="R01115"><NumCode>986</NumCode><CharCode>BRL</CharCode><Nominal>1</Nominal><Name>Áðàçèëüñêèé ðåàë</Name><Value>17,0399</Value><VunitRate>17,0399</VunitRate></Valute><Valute ID="R01135"><NumCode>348</NumCode><CharCode>HUF</CharCode><Nominal>100</Nominal><Name>Âåíãåðñêèõ ôîðèíòîâ</Name><Value>26,0370</Value><VunitRate>0,26037</VunitRate></Valute><Valute ID="R01150"><NumCode>704</NumCode><CharCode>VND</CharCode><Nominal>10000</Nominal><Name>Âüåòíàìñêèõ äîíãîâ</Name><Value>38,4412</Value><VunitRate>0,00384412</VunitRate></Valute><Valute ID="R01200"><NumCode>344</NumCode><CharCode>HKD</CharCode><Nominal>1</Nominal><Name>Ãîíêîíãñêèé äîëëàð</Name><Value>11,9475</Value><VunitRate>11,9475</VunitRate></Valute><Valute ID="R01210"><NumCode>981</NumCode><CharCode>GEL</CharCode><Nominal>1</Nominal><Name>Ãðóçèíñêèé ëàðè</Name><Value>33,9793</Value><VunitRate>33,9793</VunitRate></Valute><Valute ID="R01215"><NumCode>208</NumCode><CharCode>DKK</CharCode><Nominal>1</Nominal><Name>Äàòñêàÿ êðîíà</Name><Value>13,8685</Value><VunitRate>13,8685</VunitRate></Valute><Valute ID="R01230"><NumCode>784</NumCode><CharCode>AED</CharCode><Nominal>1</Nominal><Name>Äèðõàì ÎÀÝ</Name><Value>25,2451</Value><VunitRate>25,2451</VunitRate></Valute><Valute ID="R01235"><NumCode>840</NumCode><CharCode>USD</CharCode><Nominal>1</Nominal><Name>Äîëëàð ÑØÀ</Name><Value>92,7126</Value><VunitRate>92,7126</VunitRate></Valute><Valute ID="R01239"><NumCode>978</NumCode><CharCode>EUR</CharCode><Nominal>1</Nominal><Name>Åâðî</Name><Value>103,4694</Value><VunitRate>103,4694</VunitRate></Valute><Valute ID="R01240"><NumCode>818</NumCode><CharCode>EGP</CharCode><Nominal>10</Nominal><Name>Åãèïåòñêèõ ôóíòîâ</Name><Value>19,1730</Value><VunitRate>1,9173</VunitRate></Valute><Valute ID="R01270"><NumCode>356</NumCode><CharCode>INR</CharCode><Nominal>10</Nominal><Name>Èíäèéñêèõ ðóïèé</Name><Value>11,0809</Value><VunitRate>1,10809</VunitRate></Valute><Valute ID="R01280"><NumCode>360</NumCode><CharCode>IDR</CharCode><Nominal>10000</Nominal><Name>Èíäîíåçèéñêèõ ðóïèé</Name><Value>61,1117</Value><VunitRate>0,00611117</VunitRate></Valute><Valute ID="R01335"><NumCode>398</NumCode><CharCode>KZT</CharCode><Nominal>100</Nominal><Name>Êàçàõñòàíñêèõ òåíãå</Name><Value>19,3741</Value><VunitRate>0,193741</VunitRate></Valute><Valute ID="R01350"><NumCode>124</NumCode><CharCode>CAD</CharCode><Nominal>1</Nominal><Name>Êàíàäñêèé äîëëàð</Name><Value>68,8085</Value><VunitRate>68,8085</VunitRate></Valute><Valute ID="R01355"><NumCode>634</NumCode><CharCode>QAR</CharCode><Nominal>1</Nominal><Name>Êàòàðñêèé ðèàë</Name><Value>25,4705</Value><VunitRate>25,4705</VunitRate></Valute><Valute ID="R01370"><NumCode>417</NumCode><CharCode>KGS</CharCode><Nominal>10</Nominal><Name>Êèðãèçñêèõ ñîìîâ</Name><Value>11,0110</Value><VunitRate>1,1011</V ...

# %%
from pprint import pprint

# %%
from pprint import pprint # Импортируем функцию pprint()
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\phython3.9\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\phython3.9\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\phython3.9\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\phython3.9\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[8], line 2
#       1 from pprint import pprint # Импортируем функцию pprint()
# ----> 2 currencies = response.json() # Применяем метод json()
#       3 pprint(currencies) # Выводим результат на экран)
#
# File c:\phython3.9\lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\phython3.9\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\phython3.9\lib\site-packages (from beautifulsoup4) (2.5)

# %%
#получим информацию по тегу

# Применяем метод find() к объекту и выводим результат на экран
print(page.find('h1').text)
# Out:
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
#получим информацию o title — это строка, которая отображается на вкладке браузера:
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
#Находим заголовки любой страницы википедии
def wiki_header(url):
    page=BeautifulSoup(requests.get(url).text,'html.parser')
    header=page.find('h1').text
    return header

# %%
print(page.find('div').text) # Выводим содержимое атрибута text тега div

# %%
print(page.find('div', class_='n1_material text-18').text) # Выводим содержимое атрибута text тега div класса n1_material text-18
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.

# %%
#НАХОДИМ ДАТУ НАПИСАНИЯ СТАТЬИ
#Нам нужен тег <a> … </a> с классом "relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center". Для поиска достаточно указать в качестве класса "relative", отбросив дополнительные настройки.
print(page.find('a', class_= "relative").text)
# Out:
# 11.10.21

# %% [markdown]
# МЕТОД FIND НАХООДИТ ТОЛЬКО ПЕРВЫЙ СЛУЧАЙ

# %%
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a href="/">
# <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
# </a>

# %%
#FIND_ALL
links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 85

# %%
print([link.text for link in links[15:20]]) # Выводим ссылки с 500 по 509 включительно
# Out:
# ['Археология', 'Нейронауки', 'На мышах', 'Звук', 'Красота']

# %% [markdown]
# Запрос к API из кода

# %%
import requests # Импортируем модуль requests
token = 'c3f31817c3f31817c3f3181774c0ec79f5cc3f3c3f31817a509d538174e2321de2f1970' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bdate', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'bdate': '14.2',
#                'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'is_closed': False,
#                'last_name': ''}]}

# %%
url = 'https://api.vk.com/method/users.get'
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}
response = requests.get(url, params=params).json()['response']
men=0
women=0
for elem in response:
    if elem['sex'] == 1:
        women +=1
    if elem['sex'] == 2:
        men +=1
    else:
        continue
dolya = round((women/(men+women)), 2)
print(dolya)
# Out:
# 0.49

# %%
import requests
url = 'https://api.vk.com/method/users.get'
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}
response = requests.get(url, params=params).json()['response']
men=women=0
for elem in response:
    if elem['sex'] == 2:
        men+=1
    elif elem['sex'] == 1:
        women+=1
    else:
        continue
print(round(women/(men+women),2))
# Out:
# 0.49

# %% [markdown]
# Теперь используем count и offset, чтобы получить те же id по пять за раз:
# ОБРАЩЕНИЕ К API СО СМЕЩЕНИЕМ

# %%
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 243, 296, 345, 353, 421, 431, 450, 467, 485, 510, 550]

# %% [markdown]
# БЫ ОБОЙТИ ОГРАНИЧЕНИЕ ПО КОЛИЧЕСТВУ ЗАПРОСОВ API

# %%
import time # Импортируем модуль time

# %%
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод wall.get. Применим его:

# %%
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 768,
#               'items': [{'attachments': [{'photo': {'access_key': 'b7b29e31b9e8bafef0',
#                                                     'album_id': -7,
#                                                     'date': 1727082847,
#                                                     'id': 457352967,
#                                                     'orig_photo': {'height': 2560,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1516443,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=1280x1280',
#                                                                'width': 1280},
#                                                               {'height': 2560,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=2560x2560',
#                                                                'width': 2560},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-87.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=510x510',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'a0e341f895b15b7099'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 394,
#                                       'groups_can_post': True},
#                          'date': 1727083149,
#                          'from_id': -22822305,
#                          'hash': 'B0rEtiXaicK-rkvSZQ',
#                          'id': 1516443,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 382,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 145, 'user_reposted': 0},
#                          'text': 'Новая программа монетизации от VK Видео: '
#                                  'авторы смогут зарабатывать больше на своём '
#                                  'контенте. \n'
#                                  '\n'
#                                  'Новая программа монетизации будет работать '
#                                  'по модели Revenue Share: авторы получат от '
#                                  '50 до 80% дохода от показов рекламы в их '
#                                  'видео. Главные условия — оригинальность и '
#                                  'длительность (дольше 2 минут) роликов. \n'
#                                  '\n'
#                                  'Подключиться могут сообщества от 5 тысяч '
#                                  'подписчиков. Подробности '
#                                  '[https://vk.com/@authors-faq-novaya-programma-monetizacii-ot-vk-video|тут].',
#                          'type': 'post',
#                          'views': {'count': 170648}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'can_add': 0,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 333,
#                                                     'date': 1726757655,
#                                                     'description': 'Что можно '
#                                                                    'успеть за '
#                                                                    '60 секунд? '
#                                                                    'Очень '
#                                                                    'многое!\n'
#                                                                    '\n'
#                                                                    'Например, '
#                                                                    'постоять в '
#                                                                    'планке, '
#                                                                    'угнать '
#                                                                    'что-то, а '
#                                                                    'теперь ещё '
#                                                                    'и записать '
#                                                                    'длинную '
#                                                                    'историю '
#                                                                    'ВКонтакте!',
#                                                     'duration': 16,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=7332642753133&idx=0&type=39&tkn=ASpisrfqFbDmzXc8NvMUTc1ZFWw&fn=vid_w',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=7332642753133&idx=0&type=39&tkn=ASpisrfqFbDmzXc8NvMUTc1ZFWw&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=7332642753133&idx=0&type=39&tkn=ASpisrfqFbDmzXc8NvMUTc1ZFWw&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=7332642753133&idx=0&type=39&tkn=ASpisrfqFbDmzXc8NvMUTc1ZFWw&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=7332642753133&idx=0&type=39&tkn=ASpisrfqFbDmzXc8NvMUTc1ZFWw&fn=vid_f',
#                                                     'height': 1920,
#                                                     'id': 456242843,
#                                                     'local_views': 587281,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://sun1-89.userapi.com/impg/nx_bFny27NjBjeD98g-mxeS7_eALjgkuMYEp4A/AHZkurJL2iU.jpg?size=405x720&quality=95&sign=ad8a436aef36665f96e3dd9a2857186b&c_uniq_tag=JfLzI4rqBMsky4IFeoWrCPTcWvvWFbWSdCKeoICuK0Q&type=video_thumb',
#                                                     'photo_130': 'https://sun1-89.userapi.com/impg/nx_bFny27NjBjeD98g-mxeS7_eALjgkuMYEp4A/AHZkurJL2iU.jpg?size=130x96&quality=95&keep_aspect_ratio=1&background=000000&sign=c3026fbf36a6934dfb80d6d74ea338c8&c_uniq_tag=uQXmx5HhRIk-ZTjcVq8tN6D1YptumGtnSwgxYqQSGgQ&type=video_thumb',
#                                                     'photo_320': 'https://sun1-89.userapi.com/impg/nx_bFny27NjBjeD98g-mxeS7_eALjgkuMYEp4A/AHZkurJL2iU.jpg?size=320x240&quality=95&keep_aspect_ratio=1&background=000000&sign=a9b841207fbb0fdac4be43197321c52e&c_uniq_tag=tzEDWT3Z7zF5bMLpDLz8vylaDzsbRdJ-eHz3ji8-SpM&type=video_thumb',
#                                                     'photo_800': 'https://sun1-89.userapi.com/impg/nx_bFny27NjBjeD98g-mxeS7_eALjgkuMYEp4A/AHZkurJL2iU.jpg?size=800x450&quality=95&keep_aspect_ratio=1&background=000000&sign=8d3e8875c55e716a8a5bc1db6d00311a&c_uniq_tag=Ezm9y7N4rPsFNaG0aPLyM6f96n8PCVYGjXbc5Mnig44&type=video_thumb',
#                                                     'repeat': 1,
#                                                     'response_type': 'full',
#                                                     'title': 'Clip by @vk',
#                                                     'track_code': 'video_ac498e92VRyssXqnkflsxTAA9rAJBttQgapF7G_WY7ylgfifWwR7PbO7eq2Q-2qqNGrzsAgH12K5nnboGLcP2yNvXhA0FVYPgYNIn6PLX_UFoD16wMsQnUZhdw',
#                                                     'views': 587281,
#                                                     'wall_post_id': 1515738,
#                                                     'width': 1080}}],
#                          'comments': {'can_post': 1,
#                                       'count': 339,
#                                       'groups_can_post': True},
#                          'date': 1726757657,
#                          'from_id': -22822305,
#                          'hash': 'SGa8GUuSt4h3k1s5RQ',
#                          'id': 1515738,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1342,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 105, 'user_reposted': 0},
#                          'text': 'Что можно успеть за 60 секунд? Очень '
#                                  'многое!\n'
#                                  '\n'
#                                  'Например, постоять в планке, угнать что-то, '
#                                  'а теперь ещё и записать длинную историю '
#                                  'ВКонтакте!',
#                          'type': 'post',
#                          'views': {'count': 589788}},
#                         {'attachments': [{'photo': {'access_key': '1a4c7912afc9de54df',
#                                                     'album_id': -7,
#                                                     'date': 1726747140,
#                                                     'id': 457352910,
#                                                     'orig_photo': {'height': 2160,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu',
#                                                                    'width': 2160},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 2160,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=2160x2160',
#                                                                'width': 2160},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/MnQBvtoce1ALfLwbJUJxkmbRL0Y5htZn4w5RkwV5bDPuiB2EBElV0wDGTGFaZPOpdz9-oGGueMGib-qnyJRl1U1I.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=1280x1280',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '6c842b9de3171cca17'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': 'cedb4e51dceff4ca77',
#                                                     'album_id': -7,
#                                                     'date': 1726747140,
#                                                     'id': 457352911,
#                                                     'orig_photo': {'height': 2160,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu',
#                                                                    'width': 2160},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 2160,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=2160x2160',
#                                                                'width': 2160},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/gXgsm1_QlxCzFbvcGR-iyePgiwuSCXG33GY4EZFRsjSXMcyLNNZiDstWo2_hubgvnzHGYCN_foPK90cJRI6s94pO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=1280x1280',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'b0c3bc1db347961916'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': 'ba15eaf23214bf774e',
#                                                     'album_id': -7,
#                                                     'date': 1726747140,
#                                                     'id': 457352912,
#                                                     'orig_photo': {'height': 2160,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu',
#                                                                    'width': 2160},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 2160,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=2160x2160',
#                                                                'width': 2160},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/w-g5u--y_zlBMEUvi5nh2nnZ030Hod_RUBQShOxTMQLVrVUAQ-gHxh1nnq1u8YpZyva-Db3HQjW4X2R_5SryE4TD.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=1280x1280',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '8247ae1901db7682b3'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 316,
#                                       'groups_can_post': True},
#                          'date': 1726748100,
#                          'from_id': -22822305,
#                          'hash': 'w9uEP1GFHZhqubLoAA',
#                          'id': 1515589,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 518,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 229, 'user_reposted': 0},
#                          'text': 'Обновился VK Мессенджер в веб-версии '
#                                  'ВКонтакте! Он стал быстрее и красивее.\n'
#                                  '\n'
#                                  'Новый интерфейс ускорился на 30%, навигация '
#                                  'стала проще, появились папки для чатов. Ещё '
#                                  'в обновлённой веб-версии есть тихие и '
#                                  'исчезающие сообщения, анимации реакций и '
#                                  'возможность самому настроить оформление. \n'
#                                  '\n'
#                                  'Переключайтесь на обновлённый интерфейс в '
#                                  'меню [vk.com/im|мессенджера]!',
#                          'type': 'post',
#                          'views': {'count': 171443}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '0ee4727ef8789a69dd',
#                                                     'can_add': 1,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 151,
#                                                     'date': 1726653845,
#                                                     'description': '',
#                                                     'duration': 15,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=6879373495039&idx=0&type=39&tkn=7LTnN7oUp-7dqreUudw2pNXm1oI&fn=vid_w',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=6879373495039&idx=0&type=39&tkn=7LTnN7oUp-7dqreUudw2pNXm1oI&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=6879373495039&idx=0&type=39&tkn=7LTnN7oUp-7dqreUudw2pNXm1oI&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=6879373495039&idx=0&type=39&tkn=7LTnN7oUp-7dqreUudw2pNXm1oI&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=6879373495039&idx=0&type=39&tkn=7LTnN7oUp-7dqreUudw2pNXm1oI&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456242841,
#                                                     'local_views': 124589,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=6879373495039&idx=6&type=39&tkn=9_iInlAlmlsLtuQU2HdfMPxnvnI&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=6879373495039&idx=6&type=39&tkn=9_iInlAlmlsLtuQU2HdfMPxnvnI&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=6879373495039&idx=6&type=39&tkn=9_iInlAlmlsLtuQU2HdfMPxnvnI&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=6879373495039&idx=6&type=39&tkn=9_iInlAlmlsLtuQU2HdfMPxnvnI&fn=vid_x',
#                                                     'response_type': 'full',
#                                                     'title': 'Video by '
#                                                              'ВКонтакте',
#                                                     'track_code': 'video_2e16a984p0WHpku6A0GzD67FkGo77eKLjLt_rLYXHjuOFGu_9smWZJmkTN0ARrEKqKKQXw3f1rm0j06jwXZyV44FRo3E8aRWqmuGfc6Mf8BkZaU',
#                                                     'views': 124589,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 151,
#                                       'groups_can_post': True},
#                          'date': 1726654200,
#                          'edited': 1726660744,
#                          'from_id': -22822305,
#                          'hash': 'VGyBiZDTSwTAvUo0Dg',
#                          'id': 1515384,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 288,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 107, 'user_reposted': 0},
#                          'text': 'Представляем VK AdBlogger — новую платформу '
#                                  'для взаимодействия авторов сообществ и '
#                                  'бизнеса. Теперь монетизировать своё '
#                                  'сообщество стало ещё проще!\n'
#                                  '\n'
#                                  'VK AdBlogger помогает бизнесу находить '
#                                  'нужные сообщества, изучать их статистику и '
#                                  'напрямую договариваться о размещении '
#                                  'рекламы. Авторы же могут гибко управлять '
#                                  'процессом: назначать цены за размещение '
#                                  'поста, указывать свои свободные слоты для '
#                                  'рекламы и даже разрешить запуск кампаний без '
#                                  'согласования.\n'
#                                  '\n'
#                                  'Все процессы автоматизированы — от '
#                                  'оформления документов до маркировки и '
#                                  'оплаты. Платформа доступна на десктопе и '
#                                  'мобильных устройствах: vk.cc/cAWnlA\n'
#                                  '\n'
#                                  'Все подробности вы найдёте тут: vk.cc/cAURBo',
#                          'type': 'post',
#                          'views': {'count': 169955}},
#                         {'attachments': [{'photo': {'access_key': 'e995e97d0b7b69af3f',
#                                                     'album_id': -7,
#                                                     'date': 1726216555,
#                                                     'id': 457352795,
#                                                     'orig_photo': {'height': 1080,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-24.userapi.com/s/v1/ig2/7ngbEjyCoHuEx4xaheVYf5LubpLbGGb50kNQ1ktn82t5xpmCrhndGYwVdLg0XsJWR0g-2hO0NI8MqDU0d0cu_3Gv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-24.userapi.com/s/v1/ig2/7ngbEjyCoHuEx4xaheVYf5LubpLbGGb50kNQ1ktn82t5xpmCrhndGYwVdLg0XsJWR0g-2hO0NI8MqDU0d0cu_3Gv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-24.userapi.com/s/v1/ig2/7ngbEjyCoHuEx4xaheVYf5LubpLbGGb50kNQ1ktn82t5xpmCrhndGYwVdLg0XsJWR0g-2hO0NI8MqDU0d0cu_3Gv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-24.userapi.com/s/v1/ig2/7ngbEjyCoHuEx4xaheVYf5LubpLbGGb50kNQ1ktn82t5xpmCrhndGYwVdLg0XsJWR0g-2hO0NI8MqDU0d0cu_3Gv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-24.userapi.com/s/v1/ig2/7ngbEjyCoHuEx4xaheVYf5LubpLbGGb50kNQ1ktn82t5xpmCrhndGYwVdLg0XsJWR0g-2hO0NI8MqDU0d0cu_3Gv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
# ...
#                                                     'response_type': 'full',
#                                                     'title': 'VK ПОД ШУБОЙ 2 – '
#                                                              'трейлер',
#                                                     'track_code': 'video_f4012efageJXfThBo1dHoNab8CArdG-F3VZ9EWDeUzhyZ0al6PO6xEh8OkTLU0el0ZqaJR5CXbbkY0glb6kyVB5nV4jawYL2ek_1jmudjG8cV1AV',
#                                                     'views': 2877147,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 70,
#                                       'groups_can_post': True},
#                          'date': 1703847600,
#                          'from_id': -22822305,
#                          'hash': '39Dj5fmbYXmTNgz9ZQ',
#                          'id': 1452251,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 810,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 137, 'user_reposted': 0},
#                          'text': 'Встречаем новогодние праздники вместе с «VK '
#                                  'под шубой 2». Уже сегодня наше новогоднее '
#                                  'шоу появится тут: vk.com/vkvideo.\n'
#                                  '\n'
#                                  'Будет много юмора, неожиданных дуэтов и '
#                                  'новогоднего волшебства. Присоединяйтесь, '
#                                  'всех ждём в 20:24!',
#                          'type': 'post',
#                          'views': {'count': 488414}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '6f51ac314a0f817913',
#                                                     'can_add': 1,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 53,
#                                                     'date': 1703409722,
#                                                     'description': '',
#                                                     'duration': 15,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=5618267064901&idx=0&type=39&tkn=gikLamH5tpzji-9q_2JTSKBDrmE&fn=vid_w',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=5618267064901&idx=0&type=39&tkn=gikLamH5tpzji-9q_2JTSKBDrmE&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=5618267064901&idx=0&type=39&tkn=gikLamH5tpzji-9q_2JTSKBDrmE&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=5618267064901&idx=0&type=39&tkn=gikLamH5tpzji-9q_2JTSKBDrmE&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=5618267064901&idx=0&type=39&tkn=gikLamH5tpzji-9q_2JTSKBDrmE&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456242481,
#                                                     'local_views': 585341,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=5618267064901&idx=9&type=39&tkn=inXPGjvw7tkKE9rUGTqWhqFQY_k&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=5618267064901&idx=9&type=39&tkn=inXPGjvw7tkKE9rUGTqWhqFQY_k&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=5618267064901&idx=9&type=39&tkn=inXPGjvw7tkKE9rUGTqWhqFQY_k&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=5618267064901&idx=9&type=39&tkn=inXPGjvw7tkKE9rUGTqWhqFQY_k&fn=vid_x',
#                                                     'response_type': 'full',
#                                                     'title': 'Video by '
#                                                              'ВКонтакте',
#                                                     'track_code': 'video_c8c779aafPb0YS3hPYr-Cv7bGLi2VggiH5TqzyvWqu46gs9wjUBN1-pjKoY-jPgI-bUVjYBkPBArrNvAXLfGgjqT4kK_eH_l2azgJvBHMsU0ey0',
#                                                     'views': 585341,
#                                                     'width': 1920}},
#                                          {'link': {'description': '',
#                                                    'target': 'internal',
#                                                    'title': '51606974',
#                                                    'url': 'https://vk.com/app51606974?utm_campaign=nygiftfest&utm_source=vkontaktevideo'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 53,
#                                       'groups_can_post': True},
#                          'date': 1703836801,
#                          'from_id': -22822305,
#                          'hash': 'BpgZuWx4tF0JI_n3BA',
#                          'id': 1452219,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 707,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 97, 'user_reposted': 0},
#                          'text': 'Куручу-верчу, удачу хочу! Илья Куруч и '
#                                  'профессор Персик только что зарядили вас '
#                                  'удачей.\n'
#                                  '\n'
#                                  'Заберите свой приз на «Фестивале подарков». '
#                                  'Поторопитесь, до розыгрыша суперпризов '
#                                  'осталось 2 недели: https://vk.cc/ctrOAZ',
#                          'type': 'post',
#                          'views': {'count': 678401}},
#                         {'attachments': [{'photo': {'access_key': '242ccae40ebc64b816',
#                                                     'album_id': -7,
#                                                     'date': 1703764075,
#                                                     'id': 457345973,
#                                                     'orig_photo': {'height': 1442,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1452094,
#                                                     'sizes': [{'height': 73,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu&cs=130x73',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu&cs=200x133',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu&cs=320x213',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu&cs=510x340',
#                                                                'width': 510},
#                                                               {'height': 42,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu&cs=75x42',
#                                                                'width': 75},
#                                                               {'height': 1442,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu&cs=2560x1442',
#                                                                'width': 2560},
#                                                               {'height': 340,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu&cs=604x340',
#                                                                'width': 604},
#                                                               {'height': 455,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu&cs=807x455',
#                                                                'width': 807},
#                                                               {'height': 721,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-99.userapi.com/s/v1/ig2/UymerZ5gnKGK6WhBAa6PJT7ROK3ucyBnJ0utBD3PomryyJ004YSzI0x7b4_mIc1-rgfXzW1dtmFrBfeEq8J8Ml-Z.jpg?quality=96&as=32x18,48x27,72x41,108x61,160x90,240x135,360x203,480x270,540x304,640x360,720x406,1080x608,1280x721,1440x811,2560x1442&from=bu&cs=1280x721',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '19be4d507f899b6f08'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 70,
#                                       'groups_can_post': True},
#                          'date': 1703764500,
#                          'edited': 1703768265,
#                          'from_id': -22822305,
#                          'hash': 'fvbDyOF7IeAbii-6lg',
#                          'id': 1452094,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 564,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 92, 'user_reposted': 0},
#                          'text': 'В нашем зимнем городке с итогами года теперь '
#                                  'открыты все домики!\n'
#                                  '\n'
#                                  'Музыкальная сцена, звёздная аллея или кафе '
#                                  'свиданий — куда заглянете первым делом?\n'
#                                  '\n'
#                                  'vk.com/2023',
#                          'type': 'post',
#                          'views': {'count': 309801}}]}}

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'ВКонтакте есть ситуации, для к': [421, 677, 174, 1724414401],
#  'Какие персонажи — такие и их л': [573, 1071, 137, 1726227240],
#  'Кто знает, какой сегодня день ': [299, 797, 82, 1725376800],
#  'Кто разгадал ребус, тому завтр': [216, 1107, 92, 1725174600],
#  'Негласное правило ВКонтакте № ': [328, 811, 135, 1726056001],
#  'Новая программа монетизации от': [394, 382, 145, 1727083149],
#  'Обновился VK Мессенджер в веб-': [316, 518, 229, 1726748100],
#  'Представляем VK AdBlogger — но': [151, 288, 107, 1726654200],
#  'Согласны? Не узнали?': [409, 1901, 218, 1724749500],
#  'Что можно успеть за 60 секунд?': [339, 1342, 105, 1726757657]}
