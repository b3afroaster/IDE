# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sber_data = pd.read_csv('data/sber_data.csv')
sber_data.head()
# Out:
#    id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0   1       43     27.0    4.0           Bibirevo           5001.0
# 1   2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2   3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 3   4       89     50.0    9.0             Mitino           6839.0
# 4   5       77     77.0    4.0          Basmannoe           3240.0
#
#    preschool_education_centers_raion  school_quota  \
# 0                                  5       11065.0
# 1                                  5        6237.0
# 2                                  4        5580.0
# 3                                  9       17063.0
# 4                                  7        7770.0
#
#    school_education_centers_raion  school_education_centers_top_20_raion  ...  \
# 0                               5                                      0  ...
# 1                               8                                      0  ...
# ...

# %%
sber_data.tail()
# Out:
#           id  full_sq  life_sq  floor              sub_area  preschool_quota  \
# 30466  30469       44     27.0    7.0              Otradnoe           5088.0
# 30467  30470       86     59.0    3.0              Tverskoe           1874.0
# 30468  30471       45      NaN   10.0  Poselenie Vnukovskoe              NaN
# 30469  30472       64     32.0    5.0          Obruchevskoe           2372.0
# 30470  30473       43     28.0    1.0           Novogireevo           2215.0
#
#        preschool_education_centers_raion  school_quota  \
# 30466                                  4       12721.0
# 30467                                  4        6772.0
# 30468                                  0           NaN
# 30469                                  6        6083.0
# 30470                                  4        5824.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 30466                               4                                      0
# ...

# %%
sber_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 61 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     30471 non-null  int64
#  1   full_sq                                30471 non-null  int64
#  2   life_sq                                24088 non-null  float64
#  3   floor                                  30304 non-null  float64
#  4   sub_area                               30471 non-null  object
#  5   preschool_quota                        23783 non-null  float64
#  6   preschool_education_centers_raion      30471 non-null  int64
#  7   school_quota                           23786 non-null  float64
#  8   school_education_centers_raion         30471 non-null  int64
#  9   school_education_centers_top_20_raion  30471 non-null  int64
# ...

# %%
sber_data['sub_area'].unique().shape[0]
# Out:
# 146

# %%
sber_data['price_doc'].max()
# Out:
# 111111112

# %%
fig = plt.figure(figsize=(10, 5))
bp = sns.boxplot(
    data=sber_data,
    x='price_doc',
    y='ecology',
    orient='h',
    width=0.7
)

# %%
fig = plt.figure(figsize=(10, 5))
scd = sns.scatterplot(
    data=sber_data,
    x='price_doc',
    y='kremlin_km',

)

# %%
jointplot = sns.jointplot(
    data=sber_data,
    x='price_doc',
    y='kremlin_km',
    height=8,
)

# %%
sber_data['floor'].mode()[0]
# Out:
# 3.0

# %%
#РАСШИРЕННЫЙ МЕТОД ТЬЮКИ ДЛЯ ПОИСКА ВЫБРОСОВ

# %%
def outliers_iqr_mod(data, feature, n_iqr=1.5):
    x = data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * n_iqr)
    upper_bound = quartile_3 + (iqr * n_iqr)
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned

# %%
outliers, cleaned = outliers_iqr_mod(sber_data, 'full_sq', n_iqr=3)
print(f'Число выбросов по методу Тьюки: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу Тьюки: 236
# Результирующее число записей: 30235

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
histplot = sns.histplot(data=cleaned, x='full_sq', ax=axes[0]);
histplot.set_title('Cleaned Full Square Distribution');
boxplot = sns.boxplot(data=cleaned, x='full_sq', ax=axes[1]);
boxplot.set_title('Cleaned Full Square Boxplot');

# %%
#МЕТОД Z для поиска выбросов

# %%
def outliers_z_score_mod(data, feature, log_scale=False, left=3, right=3):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned

# %%
outliers, cleaned = outliers_z_score_mod(sber_data, 'mkad_km', right=3.5, log_scale=True)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу z-отклонения: 0
# Результирующее число записей: 30471

# %%
outliers, cleaned = outliers_z_score_mod(sber_data, 'mkad_km', right=3.5, log_scale=True)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')

# %%
#Численный показатель асиметрии для диаграммы
skew():
print(log_mkad_km.skew())
# Out:
#   Cell In[43], line 2
#     skew():
#            ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure(figsize=(15, 5))
dia = sns.histplot(
    data=sber_data,
    x='price_doc'
)
dia.axvline(sber_data['price_doc'].mean(), lw=2, color='k')
dia.axvline(sber_data['price_doc'].mean() + 3 * sber_data['price_doc'].std(), lw=2, ls='--')
dia.axvline(sber_data['price_doc'].mean() - 3 * sber_data['price_doc'].std(), lw=2, ls='--')

# %%
sber_data.head()
# Out:
#    id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0   1       43     27.0    4.0           Bibirevo           5001.0
# 1   2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2   3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 3   4       89     50.0    9.0             Mitino           6839.0
# 4   5       77     77.0    4.0          Basmannoe           3240.0
#
#    preschool_education_centers_raion  school_quota  \
# 0                                  5       11065.0
# 1                                  5        6237.0
# 2                                  4        5580.0
# 3                                  9       17063.0
# 4                                  7        7770.0
#
#    school_education_centers_raion  school_education_centers_top_20_raion  ...  \
# 0                               5                                      0  ...
# 1                               8                                      0  ...
# ...

# %%
outliners, cleaned = outliers_z_score_mod(data=sber_data, feature='price_doc', log_scale=True, left=3.7, right=3.7)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
dia = sns.histplot(
    data=cleaned,
    x='price_doc'
)
dia.axvline(cleaned['price_doc'].mean(), lw=2, color='k')
dia.axvline(cleaned['price_doc'].mean() + 3 * cleaned['price_doc'].std(), lw=2, ls='--')
dia.axvline(cleaned['price_doc'].mean() - 3 * cleaned['price_doc'].std(), lw=2, ls='--')

# %%
print(outliners.shape[0])
# Out:
# 92

# %%
#РАСШИРЕННЫЙ ЛОГАРИФМИРОВАННЫЙ МЕТОД ТЬЮКИ
def outliers_iqr_log(data, feature, n_iqr=1, log_scale=False):
    if log_scale:
        x= np.log(data[feature] + 1)
    else:
        x = data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * n_iqr)
    upper_bound = quartile_3 + (iqr * n_iqr)
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned

# %%
outliners, cleaned = outliers_iqr_log(data=sber_data, feature='price_doc', n_iqr=3, log_scale=True)

# %%
#Построим боксплоты для числовых признаков чтобы выявить выбросы

# %%
test_box = sns.boxplot(
    data=data,
    x='totChol'
)
